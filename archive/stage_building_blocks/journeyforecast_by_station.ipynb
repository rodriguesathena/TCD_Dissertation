# %%
# Re-import libraries after reset
import pandas as pd
from collections import defaultdict
from bisect import bisect_right
from functions import stop_templates
import numpy as np

file = #insert file of choice

df = pd.read_csv(file, parse_dates=["DateTime"])

# %%
def print_station_journey(df, station, service_day):
    # Filter by station and service day
    day_data = df[(df["Origin"] == station) & (df["ServiceDay"] == service_day)]

    if day_data.empty:
        print(f"No data for station {station} on {service_day}")
        return

    # Group by journey ID and sort journeys by their first DateTime
    journeys = (
        day_data.groupby("StationJourneyID")
        .apply(lambda g: g.sort_values("DateTime"))
        .reset_index(drop=True)
    )
    
    # Sort by first DateTime of each journey
    first_times = (
        journeys.groupby("StationJourneyID")["DateTime"]
        .min()
        .sort_values()
        .index.tolist()
    )

    for journey_id in first_times:
        group = journeys[journeys["StationJourneyID"] == journey_id]
        print(f"\n StationJourney {int(journey_id)} at {station} on {service_day}")
        for _, row in group.iterrows():
            print(f"  {row['DateTime']}  |  Due in: {row['Minutes']} min | Destination: {row['Destination']}")

# %%
import pandas as pd
from datetime import timedelta

def stitch_forecasts_by_station(df, max_gap_minutes=8, min_logs=5):
    df = df.sort_values(['Origin', 'ServiceDay', 'Destination', 'DateTime']).reset_index(drop=True)
    df['StationJourneyID'] = pd.NA

    journey_id = 1
    grouped = df.groupby(['Origin', 'ServiceDay', 'Destination'])

    for (station, day, dest), group in grouped:
        group = group.sort_values("DateTime")
        active_journeys = []
        journey_meta = []
        journey_timestamps = []
        journey_min_minutes = []

        for idx, row in group.iterrows():
            assigned = False
            to_remove = []

            for i in range(len(active_journeys)):
                last_idx = active_journeys[i][-1]
                last_row = group.loc[last_idx]

                time_diff = (row['DateTime'] - last_row['DateTime']).total_seconds() / 60
                minute_diff = last_row['Minutes'] - row['Minutes'] if pd.notna(row['Minutes']) and pd.notna(last_row['Minutes']) else 0
                forecast_jump = row['Minutes'] - last_row['Minutes'] if pd.notna(row['Minutes']) and pd.notna(last_row['Minutes']) else 0
                min_seen = journey_min_minutes[i]

                # Prevent duplicate timestamp inclusion
                if row['DateTime'] in journey_timestamps[i]:
                    continue

                # Allow continuation if time and countdown flow logically
                if (
                    0 <= time_diff <= max_gap_minutes and
                    -2 <= minute_diff <= 5 and  # Allow small reset tolerance
                    forecast_jump <= 3 and     # Allow for slight noise
                    not (min_seen <= 1 and forecast_jump > 3)  # Avoid real resets only if journey looks done
                ):
                    active_journeys[i].append(idx)
                    journey_meta[i] = row
                    journey_timestamps[i].add(row['DateTime'])
                    journey_min_minutes[i] = min(min_seen, row['Minutes']) if pd.notna(row['Minutes']) else min_seen
                    assigned = True
                    break

                # Mark to finalize if it's too old or clearly done
                elif time_diff > max_gap_minutes or (min_seen <= 1 and forecast_jump > 3):
                    to_remove.append(i)

            # Finalize any closed journeys
            for i in sorted(to_remove, reverse=True):
                journey = active_journeys.pop(i)
                if len(journey) >= min_logs:
                    for row_idx in journey:
                        df.at[row_idx, 'StationJourneyID'] = journey_id
                    journey_id += 1
                journey_meta.pop(i)
                journey_timestamps.pop(i)
                journey_min_minutes.pop(i)

            # Start new journey if not assigned
            if not assigned:
                active_journeys.append([idx])
                journey_meta.append(row)
                journey_timestamps.append({row['DateTime']})
                journey_min_minutes.append(row['Minutes'] if pd.notna(row['Minutes']) else float('inf'))

        # Finalize remaining journeys
        for journey in active_journeys:
            if len(journey) >= min_logs:
                for row_idx in journey:
                    df.at[row_idx, 'StationJourneyID'] = journey_id
                journey_id += 1

    return df

# %%
stitched = stitch_forecasts_by_station(df)

# %%
print_station_journey(stitched, 'HAR', '2020-01-26')
# Out:
# C:\Users\athen\AppData\Local\Temp\ipykernel_22392\3933305053.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sort_values("DateTime"))
#  StationJourney 104682 at HAR on 2020-01-26
#   2020-01-26 06:44:03  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 06:46:02  |  Due in: 15.0 min | Destination: BRI
#   2020-01-26 06:48:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 06:50:03  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 06:52:02  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 06:54:02  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 06:56:02  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 06:58:02  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 07:00:02  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 07:02:02  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104758 at HAR on 2020-01-26
#   2020-01-26 07:00:02  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 07:02:02  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 07:04:02  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 07:06:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 07:08:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 07:10:02  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 07:12:02  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 07:14:02  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 07:16:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 07:18:03  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104683 at HAR on 2020-01-26
#   2020-01-26 07:08:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 07:10:02  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 07:12:02  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 07:14:02  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 07:16:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 07:18:03  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 07:20:02  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 07:22:02  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 07:24:03  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 07:26:02  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104759 at HAR on 2020-01-26
#   2020-01-26 07:18:03  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 07:20:02  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 07:22:02  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 07:24:03  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 07:26:02  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 07:28:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 07:30:02  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 07:32:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 07:34:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 07:36:02  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104684 at HAR on 2020-01-26
#   2020-01-26 07:26:02  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 07:28:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 07:30:02  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 07:32:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 07:34:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 07:36:02  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 07:38:03  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 07:40:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 07:42:02  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 07:44:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 07:46:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104760 at HAR on 2020-01-26
#   2020-01-26 07:38:03  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 07:40:05  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 07:42:02  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 07:44:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 07:46:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 07:48:02  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 07:50:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 07:52:02  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 07:54:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 07:56:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104685 at HAR on 2020-01-26
#   2020-01-26 07:46:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 07:48:02  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 07:50:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 07:52:02  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 07:54:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 07:56:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 07:58:02  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 08:00:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 08:02:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 08:04:02  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 08:06:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104761 at HAR on 2020-01-26
#   2020-01-26 07:56:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 07:58:02  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 08:00:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 08:02:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 08:04:02  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 08:06:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 08:08:03  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 08:10:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 08:12:05  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 08:14:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 08:16:02  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 08:18:02  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104686 at HAR on 2020-01-26
#   2020-01-26 08:02:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 08:04:02  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 08:06:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 08:08:03  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 08:10:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 08:12:05  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 08:14:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 08:16:02  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 08:18:02  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 08:20:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104687 at HAR on 2020-01-26
#   2020-01-26 08:16:02  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 08:18:02  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 08:20:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 08:22:02  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 08:24:04  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 08:26:02  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 08:28:03  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 08:30:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 08:32:02  |  Due in: 1.0 min | Destination: BRI
#
#  StationJourney 104762 at HAR on 2020-01-26
#   2020-01-26 08:16:02  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 08:18:02  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 08:20:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 08:22:02  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 08:24:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 08:26:02  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 08:28:03  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 08:30:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 08:32:02  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 08:34:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 08:36:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104763 at HAR on 2020-01-26
#   2020-01-26 08:32:02  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 08:34:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 08:36:05  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 08:38:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 08:40:01  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 08:42:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 08:44:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 08:46:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 08:48:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 08:50:02  |  Due in: 0.0 min | Destination: BRO
#   2020-01-26 08:52:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104688 at HAR on 2020-01-26
#   2020-01-26 08:32:02  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 08:34:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 08:36:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 08:38:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 08:40:01  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 08:42:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 08:44:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 08:46:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 08:48:04  |  Due in: 1.0 min | Destination: BRI
#
#  StationJourney 104689 at HAR on 2020-01-26
#   2020-01-26 08:46:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 08:48:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 08:50:02  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 08:52:05  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 08:54:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 08:56:05  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 08:58:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 09:00:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 09:02:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 09:04:02  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 09:06:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104764 at HAR on 2020-01-26
#   2020-01-26 08:48:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 08:50:02  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 08:52:05  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 08:54:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 08:56:05  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 08:58:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 09:00:05  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 09:02:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 09:04:02  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 09:06:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 09:08:02  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104765 at HAR on 2020-01-26
#   2020-01-26 09:02:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 09:04:02  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 09:06:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 09:08:02  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 09:10:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 09:12:03  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 09:14:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 09:16:05  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 09:18:01  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 09:20:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104690 at HAR on 2020-01-26
#   2020-01-26 09:02:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 09:04:02  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 09:06:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 09:08:02  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 09:10:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 09:12:03  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 09:14:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 09:16:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 09:18:01  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 09:20:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104766 at HAR on 2020-01-26
#   2020-01-26 09:16:05  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 09:18:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 09:20:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 09:22:01  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 09:24:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 09:26:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 09:28:05  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 09:30:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 09:32:05  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 09:34:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 09:36:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104691 at HAR on 2020-01-26
#   2020-01-26 09:16:05  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 09:18:01  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 09:20:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 09:22:01  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 09:24:05  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 09:26:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 09:28:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 09:30:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 09:32:05  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 09:34:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 09:36:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104767 at HAR on 2020-01-26
#   2020-01-26 09:32:05  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 09:34:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 09:36:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 09:38:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 09:40:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 09:42:01  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 09:44:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 09:46:01  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 09:48:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 09:50:01  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104692 at HAR on 2020-01-26
#   2020-01-26 09:32:05  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 09:34:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 09:36:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 09:38:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 09:40:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 09:42:01  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 09:44:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 09:46:01  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 09:48:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 09:50:01  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104768 at HAR on 2020-01-26
#   2020-01-26 09:46:01  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 09:48:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 09:50:01  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 09:52:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 09:54:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 09:56:03  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 09:58:06  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 10:00:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 10:02:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 10:04:01  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 10:06:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104693 at HAR on 2020-01-26
#   2020-01-26 09:46:01  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 09:48:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 09:50:01  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 09:52:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 09:54:05  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 09:56:03  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 09:58:06  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 10:00:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 10:02:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 10:04:01  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 10:06:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104694 at HAR on 2020-01-26
#   2020-01-26 10:00:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 10:02:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 10:04:01  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 10:06:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 10:08:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 10:10:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 10:12:03  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 10:14:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 10:16:06  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 10:18:04  |  Due in: 3.0 min | Destination: BRI
#
#  StationJourney 104769 at HAR on 2020-01-26
#   2020-01-26 10:02:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 10:04:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 10:06:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 10:08:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 10:10:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 10:12:03  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 10:14:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 10:16:06  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 10:18:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 10:20:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 10:22:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104770 at HAR on 2020-01-26
#   2020-01-26 10:16:06  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 10:18:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 10:20:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 10:22:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 10:24:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 10:26:01  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 10:28:02  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 10:30:01  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 10:32:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 10:34:01  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 10:36:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104695 at HAR on 2020-01-26
#   2020-01-26 10:16:06  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 10:18:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 10:20:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 10:22:05  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 10:24:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 10:26:01  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 10:28:02  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 10:30:01  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 10:32:04  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 10:34:01  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104696 at HAR on 2020-01-26
#   2020-01-26 10:32:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 10:34:01  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 10:36:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 10:38:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 10:40:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 10:42:05  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 10:44:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 10:46:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 10:48:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 10:50:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 10:52:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104771 at HAR on 2020-01-26
#   2020-01-26 10:32:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 10:34:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 10:36:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 10:38:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 10:40:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 10:42:05  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 10:44:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 10:46:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 10:48:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 10:50:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 10:52:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104697 at HAR on 2020-01-26
#   2020-01-26 10:46:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 10:48:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 10:50:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 10:52:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 10:54:04  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 10:56:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 10:58:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 11:00:01  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 11:02:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 11:04:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 11:06:01  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104772 at HAR on 2020-01-26
#   2020-01-26 10:50:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 10:52:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 10:54:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 10:56:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 10:58:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 11:00:01  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 11:02:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 11:04:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 11:06:01  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 11:08:03  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 11:10:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104773 at HAR on 2020-01-26
#   2020-01-26 10:58:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 11:00:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 11:02:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 11:04:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 11:06:01  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 11:08:03  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 11:10:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 11:12:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 11:14:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 11:16:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 11:18:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104698 at HAR on 2020-01-26
#   2020-01-26 11:02:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 11:04:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 11:06:01  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 11:08:03  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 11:10:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 11:12:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 11:14:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 11:16:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 11:18:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 11:20:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 11:22:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104774 at HAR on 2020-01-26
#   2020-01-26 11:12:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 11:14:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 11:16:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 11:18:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 11:20:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 11:22:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 11:24:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 11:26:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 11:28:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 11:30:01  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 11:32:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104699 at HAR on 2020-01-26
#   2020-01-26 11:16:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 11:18:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 11:20:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 11:22:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 11:24:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 11:26:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 11:28:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 11:30:01  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 11:32:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 11:34:04  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 11:36:01  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104775 at HAR on 2020-01-26
#   2020-01-26 11:22:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 11:24:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 11:26:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 11:28:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 11:30:01  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 11:32:05  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 11:34:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 11:36:01  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 11:38:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 11:40:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 11:42:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104700 at HAR on 2020-01-26
#   2020-01-26 11:32:05  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 11:34:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 11:36:01  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 11:38:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 11:40:04  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 11:42:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 11:44:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 11:46:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 11:48:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 11:50:03  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 11:52:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104776 at HAR on 2020-01-26
#   2020-01-26 11:34:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 11:36:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 11:38:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 11:40:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 11:42:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 11:44:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 11:46:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 11:48:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 11:50:03  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 11:52:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 11:54:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104701 at HAR on 2020-01-26
#   2020-01-26 11:48:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 11:50:03  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 11:52:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 11:54:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 11:56:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 11:58:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 12:00:03  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 12:02:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 12:04:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 12:06:04  |  Due in: 1.0 min | Destination: BRI
#
#  StationJourney 104777 at HAR on 2020-01-26
#   2020-01-26 11:48:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 11:50:03  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 11:52:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 11:54:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 11:56:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 11:58:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 12:00:03  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 12:02:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 12:04:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 12:06:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104778 at HAR on 2020-01-26
#   2020-01-26 11:58:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 12:00:03  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 12:02:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 12:04:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 12:06:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 12:08:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 12:10:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 12:12:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 12:14:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 12:16:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 12:18:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104702 at HAR on 2020-01-26
#   2020-01-26 11:58:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 12:00:03  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 12:02:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 12:04:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 12:06:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 12:08:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 12:10:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 12:12:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 12:14:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 12:16:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 12:18:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104703 at HAR on 2020-01-26
#   2020-01-26 12:10:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 12:12:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 12:14:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 12:16:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 12:18:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 12:20:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 12:22:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 12:24:03  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 12:26:07  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 12:28:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 12:30:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 12:32:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104779 at HAR on 2020-01-26
#   2020-01-26 12:12:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 12:14:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 12:16:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 12:18:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 12:20:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 12:22:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 12:24:03  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 12:26:07  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 12:28:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 12:30:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 12:32:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104780 at HAR on 2020-01-26
#   2020-01-26 12:24:03  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 12:26:07  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 12:28:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 12:30:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 12:32:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 12:34:05  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 12:36:06  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 12:38:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 12:40:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 12:42:04  |  Due in: 1.0 min | Destination: BRO
#
#  StationJourney 104704 at HAR on 2020-01-26
#   2020-01-26 12:24:03  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 12:26:07  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 12:28:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 12:30:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 12:32:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 12:34:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 12:36:06  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 12:38:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 12:40:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 12:42:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104705 at HAR on 2020-01-26
#   2020-01-26 12:34:05  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 12:36:06  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 12:38:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 12:40:05  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 12:42:04  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 12:44:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 12:46:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 12:48:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 12:50:03  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 12:52:05  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 12:54:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 12:56:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104781 at HAR on 2020-01-26
#   2020-01-26 12:36:06  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 12:38:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 12:40:05  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 12:42:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 12:44:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 12:46:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 12:48:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 12:50:03  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 12:52:05  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 12:54:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 12:56:04  |  Due in: 1.0 min | Destination: BRO
#
#  StationJourney 104706 at HAR on 2020-01-26
#   2020-01-26 12:48:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 12:50:03  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 12:52:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 12:54:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 12:56:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 12:58:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 13:00:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 13:02:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 13:04:06  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 13:06:03  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 13:08:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104782 at HAR on 2020-01-26
#   2020-01-26 12:48:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 12:50:03  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 12:52:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 12:54:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 12:56:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 12:58:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 13:00:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 13:02:05  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 13:04:06  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 13:06:03  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104707 at HAR on 2020-01-26
#   2020-01-26 12:58:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 13:00:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 13:02:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 13:04:06  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 13:06:03  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 13:08:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 13:10:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 13:12:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 13:14:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 13:16:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 13:18:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104783 at HAR on 2020-01-26
#   2020-01-26 12:58:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 13:00:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:02:05  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 13:04:06  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 13:06:03  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 13:08:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 13:10:05  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 13:12:05  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 13:14:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 13:16:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 13:18:04  |  Due in: 0.0 min | Destination: BRO
#   2020-01-26 13:20:07  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104708 at HAR on 2020-01-26
#   2020-01-26 13:12:05  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 13:14:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 13:16:05  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 13:18:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 13:20:07  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 13:22:03  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 13:24:06  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 13:26:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 13:28:06  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104784 at HAR on 2020-01-26
#   2020-01-26 13:12:05  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 13:14:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:16:05  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 13:18:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 13:20:07  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 13:22:03  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 13:24:06  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 13:26:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 13:28:06  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 13:30:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 13:32:01  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 13:34:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104709 at HAR on 2020-01-26
#   2020-01-26 13:22:03  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 13:24:06  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 13:26:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 13:28:06  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 13:30:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 13:32:01  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 13:34:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 13:36:06  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 13:38:06  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 13:40:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 13:42:06  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104785 at HAR on 2020-01-26
#   2020-01-26 13:24:06  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:26:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 13:28:06  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 13:30:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 13:32:01  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 13:34:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 13:36:06  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 13:38:06  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 13:40:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 13:42:06  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104710 at HAR on 2020-01-26
#   2020-01-26 13:34:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 13:36:06  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 13:38:06  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 13:40:05  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 13:42:06  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 13:44:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 13:46:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 13:48:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 13:50:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 13:52:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 13:54:05  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 13:56:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104786 at HAR on 2020-01-26
#   2020-01-26 13:34:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 13:36:06  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:38:06  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:40:05  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:46:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 13:50:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 13:52:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 13:54:05  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 13:56:05  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 13:58:06  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 14:00:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 14:02:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 14:04:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 14:06:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 14:08:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 14:10:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104711 at HAR on 2020-01-26
#   2020-01-26 13:46:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 13:48:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 13:50:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 13:52:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 13:54:05  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 13:56:05  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 13:58:06  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 14:00:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 14:02:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 14:04:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 14:06:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104712 at HAR on 2020-01-26
#   2020-01-26 13:58:06  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 14:00:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 14:02:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 14:04:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 14:06:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 14:08:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 14:10:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 14:12:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 14:14:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 14:16:02  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 14:18:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104787 at HAR on 2020-01-26
#   2020-01-26 14:00:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 14:02:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 14:04:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 14:06:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 14:08:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 14:10:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 14:12:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 14:14:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 14:16:02  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 14:18:05  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 14:20:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104788 at HAR on 2020-01-26
#   2020-01-26 14:12:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 14:14:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 14:16:02  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 14:18:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 14:20:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 14:22:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 14:24:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 14:26:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 14:28:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 14:30:05  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 14:32:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104713 at HAR on 2020-01-26
#   2020-01-26 14:12:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 14:14:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 14:16:02  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 14:18:05  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 14:20:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 14:22:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 14:24:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 14:26:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 14:28:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 14:30:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 14:32:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104714 at HAR on 2020-01-26
#   2020-01-26 14:22:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 14:24:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 14:26:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 14:28:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 14:30:05  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 14:32:05  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 14:34:06  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 14:36:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 14:38:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 14:40:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 14:42:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104789 at HAR on 2020-01-26
#   2020-01-26 14:24:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 14:26:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 14:28:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 14:30:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 14:32:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 14:34:06  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 14:36:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 14:38:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 14:40:05  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 14:42:05  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 14:44:06  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104715 at HAR on 2020-01-26
#   2020-01-26 14:34:06  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 14:36:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 14:38:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 14:40:05  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 14:42:05  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 14:44:06  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 14:46:07  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 14:48:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 14:50:02  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 14:52:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104790 at HAR on 2020-01-26
#   2020-01-26 14:36:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 14:38:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 14:40:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 14:42:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 14:44:06  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 14:46:07  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 14:48:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 14:50:02  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 14:52:04  |  Due in: 1.0 min | Destination: BRO
#
#  StationJourney 104716 at HAR on 2020-01-26
#   2020-01-26 14:46:07  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 14:48:04  |  Due in: 17.0 min | Destination: BRI
# ...
#   2020-01-26 20:48:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 20:50:03  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 20:52:02  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 20:54:05  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 20:56:03  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 20:58:04  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 21:00:03  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 21:02:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 21:04:01  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 21:06:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104821 at HAR on 2020-01-26
#   2020-01-26 20:46:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 20:48:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 20:50:03  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 20:52:02  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 20:54:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 20:56:03  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 20:58:04  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 21:00:03  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 21:02:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 21:04:01  |  Due in: 1.0 min | Destination: BRO
#
#  StationJourney 104747 at HAR on 2020-01-26
#   2020-01-26 21:00:03  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 21:02:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 21:04:01  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 21:06:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 21:08:02  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 21:10:06  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 21:12:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 21:14:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 21:16:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 21:18:05  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 21:20:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104822 at HAR on 2020-01-26
#   2020-01-26 21:02:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 21:04:01  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 21:06:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 21:08:02  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 21:10:06  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 21:12:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 21:14:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 21:16:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 21:18:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 21:20:04  |  Due in: 0.0 min | Destination: BRO
#   2020-01-26 21:22:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104748 at HAR on 2020-01-26
#   2020-01-26 21:10:06  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 21:12:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 21:14:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 21:16:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 21:18:05  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 21:20:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 21:22:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 21:24:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 21:26:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 21:28:06  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 21:30:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 21:32:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104823 at HAR on 2020-01-26
#   2020-01-26 21:16:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 21:18:05  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 21:20:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 21:22:04  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 21:24:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 21:26:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 21:28:06  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 21:30:05  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 21:32:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 21:34:05  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 21:36:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104749 at HAR on 2020-01-26
#   2020-01-26 21:24:05  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 21:26:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 21:28:06  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 21:30:05  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 21:32:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 21:34:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 21:36:04  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 21:38:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 21:40:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104824 at HAR on 2020-01-26
#   2020-01-26 21:32:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 21:34:05  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 21:36:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 21:38:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 21:40:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 21:42:07  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 21:44:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 21:46:05  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 21:48:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 21:50:04  |  Due in: 0.0 min | Destination: BRO
#   2020-01-26 21:52:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104750 at HAR on 2020-01-26
#   2020-01-26 21:38:04  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 21:40:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 21:42:07  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 21:44:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 21:46:05  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 21:48:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 21:50:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 21:52:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 21:54:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 21:56:05  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 21:58:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104825 at HAR on 2020-01-26
#   2020-01-26 21:48:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 21:50:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 21:52:05  |  Due in: 14.0 min | Destination: BRO
#   2020-01-26 21:54:04  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 21:56:05  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 21:58:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 22:00:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 22:02:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 22:04:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 22:06:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 22:08:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104751 at HAR on 2020-01-26
#   2020-01-26 21:54:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 21:56:05  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 21:58:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 22:00:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 22:02:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 22:04:05  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 22:06:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 22:08:05  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 22:10:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 22:12:04  |  Due in: 1.0 min | Destination: BRI
#   2020-01-26 22:14:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104826 at HAR on 2020-01-26
#   2020-01-26 22:02:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 22:04:05  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 22:06:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 22:08:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 22:10:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 22:12:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 22:14:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 22:16:01  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 22:18:20  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 22:20:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 22:22:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104752 at HAR on 2020-01-26
#   2020-01-26 22:08:05  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 22:10:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 22:12:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 22:14:04  |  Due in: 12.0 min | Destination: BRI
#   2020-01-26 22:16:01  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 22:18:20  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 22:20:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 22:22:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 22:24:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 22:26:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 22:28:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104827 at HAR on 2020-01-26
#   2020-01-26 22:16:01  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 22:18:20  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 22:20:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 22:22:05  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 22:24:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 22:26:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 22:28:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 22:30:02  |  Due in: 7.0 min | Destination: BRO
#   2020-01-26 22:32:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 22:34:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 22:36:04  |  Due in: 1.0 min | Destination: BRO
#   2020-01-26 22:38:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104753 at HAR on 2020-01-26
#   2020-01-26 22:24:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 22:26:04  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 22:28:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 22:30:02  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 22:32:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 22:34:05  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 22:36:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 22:38:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 22:40:05  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 22:42:04  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 22:44:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104828 at HAR on 2020-01-26
#   2020-01-26 22:32:04  |  Due in: 19.0 min | Destination: BRO
#   2020-01-26 22:34:05  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 22:36:04  |  Due in: 16.0 min | Destination: BRO
#   2020-01-26 22:38:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 22:40:05  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 22:42:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 22:44:04  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 22:46:05  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 22:48:05  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 22:50:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 22:52:14  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104754 at HAR on 2020-01-26
#   2020-01-26 22:38:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 22:40:05  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 22:42:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 22:44:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 22:46:05  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 22:48:05  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 22:50:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 22:52:14  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 22:54:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 22:56:05  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104829 at HAR on 2020-01-26
#   2020-01-26 22:48:05  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 22:50:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 22:52:14  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 22:54:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 22:56:05  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 22:58:04  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 23:00:01  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 23:02:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 23:04:05  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 23:06:05  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104755 at HAR on 2020-01-26
#   2020-01-26 22:54:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 22:56:05  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 22:58:04  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 23:00:01  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 23:02:04  |  Due in: 9.0 min | Destination: BRI
#   2020-01-26 23:04:05  |  Due in: 7.0 min | Destination: BRI
#   2020-01-26 23:06:05  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 23:08:05  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 23:10:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104830 at HAR on 2020-01-26
#   2020-01-26 23:02:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 23:04:05  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 23:06:05  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 23:08:05  |  Due in: 12.0 min | Destination: BRO
#   2020-01-26 23:10:04  |  Due in: 10.0 min | Destination: BRO
#   2020-01-26 23:12:03  |  Due in: 8.0 min | Destination: BRO
#   2020-01-26 23:14:04  |  Due in: 5.0 min | Destination: BRO
#   2020-01-26 23:16:04  |  Due in: 3.0 min | Destination: BRO
#   2020-01-26 23:18:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 23:20:04  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104756 at HAR on 2020-01-26
#   2020-01-26 23:08:05  |  Due in: 19.0 min | Destination: BRI
#   2020-01-26 23:10:04  |  Due in: 17.0 min | Destination: BRI
#   2020-01-26 23:12:03  |  Due in: 14.0 min | Destination: BRI
#   2020-01-26 23:14:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 23:16:04  |  Due in: 10.0 min | Destination: BRI
#   2020-01-26 23:18:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 23:20:04  |  Due in: 6.0 min | Destination: BRI
#   2020-01-26 23:22:04  |  Due in: 4.0 min | Destination: BRI
#   2020-01-26 23:24:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 23:26:01  |  Due in: 0.0 min | Destination: BRI
#   2020-01-26 23:28:04  |  Due in: 0.0 min | Destination: BRI
#
#  StationJourney 104831 at HAR on 2020-01-26
#   2020-01-26 23:16:04  |  Due in: 18.0 min | Destination: BRO
#   2020-01-26 23:18:04  |  Due in: 17.0 min | Destination: BRO
#   2020-01-26 23:20:04  |  Due in: 15.0 min | Destination: BRO
#   2020-01-26 23:22:04  |  Due in: 13.0 min | Destination: BRO
#   2020-01-26 23:24:04  |  Due in: 11.0 min | Destination: BRO
#   2020-01-26 23:26:01  |  Due in: 9.0 min | Destination: BRO
#   2020-01-26 23:28:04  |  Due in: 6.0 min | Destination: BRO
#   2020-01-26 23:30:04  |  Due in: 4.0 min | Destination: BRO
#   2020-01-26 23:32:04  |  Due in: 2.0 min | Destination: BRO
#   2020-01-26 23:34:04  |  Due in: 0.0 min | Destination: BRO
#   2020-01-26 23:36:01  |  Due in: 0.0 min | Destination: BRO
#
#  StationJourney 104757 at HAR on 2020-01-26
#   2020-01-26 23:24:04  |  Due in: 18.0 min | Destination: BRI
#   2020-01-26 23:26:01  |  Due in: 16.0 min | Destination: BRI
#   2020-01-26 23:28:04  |  Due in: 13.0 min | Destination: BRI
#   2020-01-26 23:30:04  |  Due in: 11.0 min | Destination: BRI
#   2020-01-26 23:32:04  |  Due in: 8.0 min | Destination: BRI
#   2020-01-26 23:34:04  |  Due in: 5.0 min | Destination: BRI
#   2020-01-26 23:36:01  |  Due in: 3.0 min | Destination: BRI
#   2020-01-26 23:38:04  |  Due in: 2.0 min | Destination: BRI
#   2020-01-26 23:40:04  |  Due in: 0.0 min | Destination: BRI

# %%
# Count total logs with no journey assigned
num_unassigned = stitched['StationJourneyID'].isna().sum()

# Total logs overall (optional context)
total_logs = len(stitched)

print(f"⚠️ {num_unassigned} out of {total_logs} logs were unassigned ({(num_unassigned/total_logs)*100:.2f}%)")
# Out:
# ⚠️ 50641 out of 2162268 logs were unassigned (2.34%)

# %%
# # View some unassigned logs
# unassigned_logs = stitched[stitched['StationJourneyID'].isna()]
# print(unassigned_logs)

# %%
stitched.to_csv('january_2020_stations.csv', index=False)

# %%
stitched['Destination'].value_counts()
# Out:
# Destination
# TPT    383017
# BRI    354635
# TAL    305621
# BRO    301423
# SAG    243850
# PAR    228271
# SAN    185960
# CON    132961
# BEL     21357
# RED      3855
# HEU      1318
# Name: count, dtype: int64
