# %%
# Re-import libraries after reset
import pandas as pd
from collections import defaultdict
from bisect import bisect_right
from functions import stop_templates
import numpy as np

file = #insert file of choice

df = pd.read_csv(file, parse_dates=["DateTime"])

# %%
def print_station(df, station, service_day):
    # Filter by station and service day
    day_data = df[(df["Origin"] == station) & (df["ServiceDay"] == service_day)]

    if day_data.empty:
        print(f"No data for station {station} on {service_day}")
        return

    # Group by journey ID and sort journeys by their first DateTime
    journeys = (
        day_data.groupby("StationJourneyID")
        .apply(lambda g: g.sort_values("DateTime"))
        .reset_index(drop=True)
    )
    
    # Sort by first DateTime of each journey
    first_times = (
        journeys.groupby("StationJourneyID")["DateTime"]
        .min()
        .sort_values()
        .index.tolist()
    )

    for journey_id in first_times:
        group = journeys[journeys["StationJourneyID"] == journey_id]
        print(f"\nStationJourney {int(journey_id)} at {station} on {service_day}")
        for _, row in group.iterrows():
            print(f"  {row['DateTime']}  |  Due in: {row['Minutes']} min | Destination: {row['Destination']}")

def print_journey(df, journey_id, stop_templates):
    journey_df = df[df["TramJourneyID"] == journey_id].copy()

    if journey_df.empty:
        print(f"No {journey_id}")
        return

    # Attempt to extract (origin, destination) from journey ID using known templates
    def find_route_from_id(jid):
        for (start, end) in stop_templates:
            if start in jid and end in jid and jid.index(start) < jid.index(end):
                return start, end
        return None, None

    origin, destination = find_route_from_id(journey_id)

    if origin and destination and (origin, destination) in stop_templates:
        stop_order = stop_templates[(origin, destination)]
    else:
        print(f"No stop template found\n")
        stop_order = sorted(journey_df["Origin"].unique())

    print(f"TramJourney {journey_id} ({origin or '???'} → {destination or '???'})\n")

    for stop in stop_order:
        stop_logs = journey_df[journey_df["Origin"] == stop].sort_values("DateTime")
        if stop_logs.empty:
            continue
        print(f"{stop}")
        for _, row in stop_logs.iterrows():
            dt = row["DateTime"].strftime("%Y-%m-%d %H:%M:%S")
            due = f"{row['Minutes']:.1f} min"
            print(f"  {dt} | Due in: {due}")
        print()

# %%
import pandas as pd
from datetime import timedelta

def stitch_forecasts_by_station(df, max_gap_minutes=8, min_logs=5):
    df = df.sort_values(['Origin', 'ServiceDay', 'Destination', 'DateTime']).reset_index(drop=True)
    df['StationJourneyID'] = pd.NA

    journey_id = 1
    grouped = df.groupby(['Origin', 'ServiceDay', 'Destination'])

    for (station, day, dest), group in grouped:
        group = group.sort_values("DateTime")
        active_journeys = []
        journey_meta = []
        journey_timestamps = []
        journey_min_minutes = []

        for idx, row in group.iterrows():
            assigned = False
            to_remove = []

            for i in range(len(active_journeys)):
                last_idx = active_journeys[i][-1]
                last_row = group.loc[last_idx]

                time_diff = (row['DateTime'] - last_row['DateTime']).total_seconds() / 60
                minute_diff = last_row['Minutes'] - row['Minutes'] if pd.notna(row['Minutes']) and pd.notna(last_row['Minutes']) else 0
                forecast_jump = row['Minutes'] - last_row['Minutes'] if pd.notna(row['Minutes']) and pd.notna(last_row['Minutes']) else 0
                min_seen = journey_min_minutes[i]

                # Prevent duplicate timestamp inclusion
                if row['DateTime'] in journey_timestamps[i]:
                    continue

                # Allow continuation if time and countdown flow logically
                if (
                    0 <= time_diff <= max_gap_minutes and
                    -2 <= minute_diff <= 5 and  # Allow small reset tolerance
                    forecast_jump <= 3 and     # Allow for slight noise
                    not (min_seen <= 1 and forecast_jump > 3)  # Avoid real resets only if journey looks done
                ):
                    active_journeys[i].append(idx)
                    journey_meta[i] = row
                    journey_timestamps[i].add(row['DateTime'])
                    journey_min_minutes[i] = min(min_seen, row['Minutes']) if pd.notna(row['Minutes']) else min_seen
                    assigned = True
                    break

                # Mark to finalize if it's too old or clearly done
                elif time_diff > max_gap_minutes or (min_seen <= 1 and forecast_jump > 3):
                    to_remove.append(i)

            # Finalize any closed journeys
            for i in sorted(to_remove, reverse=True):
                journey = active_journeys.pop(i)
                if len(journey) >= min_logs:
                    for row_idx in journey:
                        df.at[row_idx, 'StationJourneyID'] = journey_id
                    journey_id += 1
                journey_meta.pop(i)
                journey_timestamps.pop(i)
                journey_min_minutes.pop(i)

            # Start new journey if not assigned
            if not assigned:
                active_journeys.append([idx])
                journey_meta.append(row)
                journey_timestamps.append({row['DateTime']})
                journey_min_minutes.append(row['Minutes'] if pd.notna(row['Minutes']) else float('inf'))

        # Finalize remaining journeys
        for journey in active_journeys:
            if len(journey) >= min_logs:
                for row_idx in journey:
                    df.at[row_idx, 'StationJourneyID'] = journey_id
                journey_id += 1

    return df

# %%
station_logs = stitch_forecasts_by_station(df)

# %%
from collections import defaultdict
import pandas as pd

def build_clean_tram_journeys(df, stop_templates, max_gap_min=6, allow_missing=1, min_stops=6, verbose=True):
    df = df.copy()
    df["EstimatedArrival"] = df["DateTime"] + pd.to_timedelta(df["Minutes"], unit="m")
    df["ServiceDate"] = df["DateTime"].dt.date

    # Step 1: Group logs by StationJourneyID and extract metadata
    grouped = df.groupby("StationJourneyID")
    sjid_info = []
    for sjid, group in grouped:
        dest = group["Destination"].iloc[0]
        station = group["Origin"].iloc[0]
        eta = group["EstimatedArrival"].max()
        date = group["ServiceDate"].iloc[0]
        sjid_info.append({
            "StationJourneyID": sjid,
            "Station": station,
            "Destination": dest,
            "EstimatedArrival": eta,
            "ServiceDate": date
        })

    sjid_df = pd.DataFrame(sjid_info)
    used_ids = set()
    journeys = []
    journey_counts = defaultdict(lambda: defaultdict(int))  # (origin, dest) → date → counter

    # Step 2: Loop over templates
    for (start, end), template in stop_templates.items():
        for date in sjid_df["ServiceDate"].unique():
            candidates = sjid_df[
                (sjid_df["Destination"] == end) &
                (sjid_df["ServiceDate"] == date)
            ]

            starters = candidates[candidates["Station"] == start].sort_values("EstimatedArrival")

            for _, start_row in starters.iterrows():
                if start_row["StationJourneyID"] in used_ids:
                    continue

                block = [start_row["StationJourneyID"]]
                current_time = start_row["EstimatedArrival"]
                missing = 0
                valid = True

                for stop in template[1:]:
                    possible = candidates[
                        (candidates["Station"] == stop) &
                        (~candidates["StationJourneyID"].isin(used_ids))
                    ]
                    possible = possible[possible["EstimatedArrival"].between(
                        current_time, current_time + pd.Timedelta(minutes=max_gap_min)
                    )].sort_values("EstimatedArrival")

                    if possible.empty:
                        missing += 1
                        if missing > allow_missing:
                            valid = False
                            break
                    else:
                        next_row = possible.iloc[0]
                        block.append(next_row["StationJourneyID"])
                        current_time = next_row["EstimatedArrival"]

                if valid and len(block) >= min_stops:
                    journey_counts[(start, end)][date] += 1
                    jid = f"{start}_{end}{journey_counts[(start, end)][date]:02d}_{date.year}_{date.month:02d}_{date.day:02d}"
                    matched_rows = df[df["StationJourneyID"].isin(block)].copy()
                    matched_rows["TramJourneyID"] = jid
                    journeys.append(matched_rows)
                    used_ids.update(block)

                    if verbose:
                        print(f"Built journey {jid} with {len(block)} stops")

    if not journeys:
        return pd.DataFrame()

    return pd.concat(journeys, ignore_index=True)

# %%
full_journeys = build_clean_tram_journeys(station_logs, stop_templates)
# Out:
# Built journey BRI_BRO01_2020_01_20 with 31 stops
# Built journey BRI_BRO02_2020_01_20 with 31 stops
# Built journey BRI_BRO03_2020_01_20 with 31 stops
# Built journey BRI_BRO04_2020_01_20 with 31 stops
# Built journey BRI_BRO05_2020_01_20 with 31 stops
# Built journey BRI_BRO06_2020_01_20 with 31 stops
# Built journey BRI_BRO07_2020_01_20 with 31 stops
# Built journey BRI_BRO08_2020_01_20 with 31 stops
# Built journey BRI_BRO09_2020_01_20 with 31 stops
# Built journey BRI_BRO10_2020_01_20 with 31 stops
# Built journey BRI_BRO11_2020_01_20 with 31 stops
# Built journey BRI_BRO12_2020_01_20 with 31 stops
# Built journey BRI_BRO13_2020_01_20 with 31 stops
# Built journey BRI_BRO01_2020_01_21 with 31 stops
# Built journey BRI_BRO02_2020_01_21 with 31 stops
# Built journey BRI_BRO03_2020_01_21 with 31 stops
# Built journey BRI_BRO04_2020_01_21 with 31 stops
# Built journey BRI_BRO05_2020_01_21 with 31 stops
# Built journey BRI_BRO06_2020_01_21 with 31 stops
# Built journey BRI_BRO07_2020_01_21 with 31 stops
# Built journey BRI_BRO08_2020_01_21 with 31 stops
# Built journey BRI_BRO09_2020_01_21 with 31 stops
# Built journey BRI_BRO10_2020_01_21 with 31 stops
# Built journey BRI_BRO11_2020_01_21 with 31 stops
# Built journey BRI_BRO12_2020_01_21 with 31 stops
# Built journey BRI_BRO13_2020_01_21 with 31 stops
# Built journey BRI_BRO14_2020_01_21 with 31 stops
# Built journey BRI_BRO15_2020_01_21 with 31 stops
# Built journey BRI_BRO16_2020_01_21 with 31 stops
# Built journey BRI_BRO17_2020_01_21 with 31 stops
# Built journey BRI_BRO18_2020_01_21 with 31 stops
# Built journey BRI_BRO01_2020_01_22 with 31 stops
# Built journey BRI_BRO02_2020_01_22 with 31 stops
# Built journey BRI_BRO03_2020_01_22 with 31 stops
# Built journey BRI_BRO04_2020_01_22 with 31 stops
# Built journey BRI_BRO05_2020_01_22 with 31 stops
# Built journey BRI_BRO06_2020_01_22 with 31 stops
# Built journey BRI_BRO07_2020_01_22 with 31 stops
# Built journey BRI_BRO08_2020_01_22 with 31 stops
# Built journey BRI_BRO09_2020_01_22 with 31 stops
# Built journey BRI_BRO10_2020_01_22 with 31 stops
# Built journey BRI_BRO11_2020_01_22 with 31 stops
# Built journey BRI_BRO12_2020_01_22 with 31 stops
# Built journey BRI_BRO13_2020_01_22 with 31 stops
# Built journey BRI_BRO14_2020_01_22 with 31 stops
# Built journey BRI_BRO01_2020_01_23 with 31 stops
# Built journey BRI_BRO02_2020_01_23 with 31 stops
# Built journey BRI_BRO03_2020_01_23 with 31 stops
# Built journey BRI_BRO04_2020_01_23 with 31 stops
# Built journey BRI_BRO05_2020_01_23 with 31 stops
# Built journey BRI_BRO06_2020_01_23 with 31 stops
# Built journey BRI_BRO07_2020_01_23 with 31 stops
# Built journey BRI_BRO08_2020_01_23 with 31 stops
# Built journey BRI_BRO09_2020_01_23 with 31 stops
# Built journey BRI_BRO10_2020_01_23 with 31 stops
# Built journey BRI_BRO11_2020_01_23 with 31 stops
# Built journey BRI_BRO12_2020_01_23 with 31 stops
# Built journey BRI_BRO13_2020_01_23 with 31 stops
# Built journey BRI_BRO14_2020_01_23 with 31 stops
# Built journey BRI_BRO15_2020_01_23 with 31 stops
# Built journey BRI_BRO16_2020_01_23 with 31 stops
# Built journey BRI_BRO01_2020_01_24 with 31 stops
# Built journey BRI_BRO02_2020_01_24 with 31 stops
# Built journey BRI_BRO03_2020_01_24 with 31 stops
# Built journey BRI_BRO04_2020_01_24 with 31 stops
# Built journey BRI_BRO05_2020_01_24 with 31 stops
# Built journey BRI_BRO06_2020_01_24 with 31 stops
# Built journey BRI_BRO07_2020_01_24 with 31 stops
# Built journey BRI_BRO08_2020_01_24 with 31 stops
# Built journey BRI_BRO09_2020_01_24 with 31 stops
# Built journey BRI_BRO10_2020_01_24 with 31 stops
# Built journey BRI_BRO11_2020_01_24 with 31 stops
# Built journey BRI_BRO12_2020_01_24 with 31 stops
# Built journey BRI_BRO13_2020_01_24 with 31 stops
# Built journey BRI_BRO14_2020_01_24 with 31 stops
# Built journey BRI_BRO15_2020_01_24 with 31 stops
# Built journey BRI_BRO16_2020_01_24 with 31 stops
# Built journey BRI_BRO17_2020_01_24 with 31 stops
# Built journey BRI_BRO18_2020_01_24 with 31 stops
# Built journey BRI_BRO01_2020_01_25 with 31 stops
# Built journey BRI_BRO02_2020_01_25 with 31 stops
# Built journey BRI_BRO03_2020_01_25 with 31 stops
# Built journey BRI_BRO04_2020_01_25 with 31 stops
# Built journey BRI_BRO05_2020_01_25 with 31 stops
# Built journey BRI_BRO06_2020_01_25 with 31 stops
# Built journey BRI_BRO07_2020_01_25 with 31 stops
# Built journey BRI_BRO08_2020_01_25 with 31 stops
# Built journey BRI_BRO09_2020_01_25 with 31 stops
# Built journey BRI_BRO10_2020_01_25 with 31 stops
# Built journey BRI_BRO11_2020_01_25 with 31 stops
# Built journey BRI_BRO12_2020_01_25 with 31 stops
# Built journey BRI_BRO01_2020_01_26 with 31 stops
# Built journey BRI_BRO02_2020_01_26 with 31 stops
# Built journey BRI_BRO03_2020_01_26 with 31 stops
# Built journey BRI_BRO04_2020_01_26 with 31 stops
# Built journey BRI_BRO05_2020_01_26 with 31 stops
# Built journey BRI_BRO06_2020_01_26 with 31 stops
# Built journey BRI_BRO07_2020_01_26 with 31 stops
# Built journey BRI_BRO08_2020_01_26 with 31 stops
# Built journey BRI_BRO09_2020_01_26 with 31 stops
# Built journey BRI_BRO10_2020_01_26 with 31 stops
# Built journey BRI_BRO11_2020_01_26 with 31 stops
# Built journey BRI_BRO12_2020_01_26 with 31 stops
# Built journey BRI_BRO13_2020_01_26 with 31 stops
# Built journey BRI_BRO14_2020_01_26 with 31 stops
# Built journey BRI_BRO15_2020_01_26 with 31 stops
# Built journey BRI_BRO16_2020_01_26 with 31 stops
# Built journey BRI_BRO17_2020_01_26 with 31 stops
# Built journey BRI_BRO18_2020_01_26 with 31 stops
# Built journey BRI_BRO19_2020_01_26 with 31 stops
# Built journey BRI_BRO20_2020_01_26 with 31 stops
# Built journey BRI_BRO21_2020_01_26 with 31 stops
# Built journey BRI_BRO22_2020_01_26 with 31 stops
# Built journey BRI_BRO23_2020_01_26 with 31 stops
# Built journey BRI_BRO24_2020_01_26 with 31 stops
# Built journey BRI_BRO25_2020_01_26 with 31 stops
# Built journey BRI_BRO26_2020_01_26 with 31 stops
# Built journey BRI_BRO27_2020_01_26 with 31 stops
# Built journey BRI_BRO28_2020_01_26 with 31 stops
# Built journey BRI_BRO29_2020_01_26 with 31 stops
# Built journey BRI_BRO30_2020_01_26 with 31 stops
# Built journey BRI_BRO31_2020_01_26 with 31 stops
# Built journey BRI_BRO32_2020_01_26 with 31 stops
# Built journey BRI_BRO33_2020_01_26 with 31 stops
# Built journey BRI_BRO34_2020_01_26 with 31 stops
# Built journey BRI_BRO35_2020_01_26 with 31 stops
# Built journey BRI_BRO36_2020_01_26 with 31 stops
# Built journey BRI_BRO37_2020_01_26 with 31 stops
# Built journey BRI_BRO38_2020_01_26 with 31 stops
# Built journey BRI_BRO39_2020_01_26 with 31 stops
# Built journey BRI_BRO40_2020_01_26 with 31 stops
# Built journey BRI_BRO41_2020_01_26 with 31 stops
# Built journey BRI_BRO42_2020_01_26 with 31 stops
# Built journey BRI_BRO43_2020_01_26 with 31 stops
# Built journey BRI_BRO44_2020_01_26 with 31 stops
# Built journey BRI_BRO45_2020_01_26 with 31 stops
# Built journey BRI_BRO46_2020_01_26 with 31 stops
# Built journey BRI_BRO47_2020_01_26 with 31 stops
# Built journey BRI_BRO48_2020_01_26 with 31 stops
# Built journey BRI_BRO49_2020_01_26 with 31 stops
# Built journey BRI_BRO50_2020_01_26 with 31 stops
# Built journey BRI_BRO51_2020_01_26 with 31 stops
# Built journey BRI_BRO52_2020_01_26 with 31 stops
# Built journey BRI_BRO53_2020_01_26 with 31 stops
# Built journey BRI_BRO54_2020_01_26 with 31 stops
# Built journey BRI_BRO55_2020_01_26 with 31 stops
# Built journey BRI_BRO56_2020_01_26 with 31 stops
# Built journey BRI_BRO57_2020_01_26 with 31 stops
# Built journey BRI_BRO01_2020_01_27 with 31 stops
# Built journey BRI_BRO02_2020_01_27 with 31 stops
# Built journey BRI_BRO03_2020_01_27 with 31 stops
# Built journey BRI_BRO04_2020_01_27 with 31 stops
# Built journey BRI_BRO05_2020_01_27 with 31 stops
# Built journey BRI_BRO06_2020_01_27 with 31 stops
# Built journey BRI_BRO07_2020_01_27 with 31 stops
# Built journey BRI_BRO08_2020_01_27 with 31 stops
# Built journey BRI_BRO09_2020_01_27 with 31 stops
# Built journey BRI_BRO10_2020_01_27 with 31 stops
# Built journey BRI_BRO11_2020_01_27 with 31 stops
# Built journey BRI_BRO12_2020_01_27 with 31 stops
# Built journey BRI_BRO13_2020_01_27 with 31 stops
# Built journey BRI_BRO01_2020_01_28 with 31 stops
# Built journey BRI_BRO02_2020_01_28 with 31 stops
# Built journey BRI_BRO03_2020_01_28 with 31 stops
# Built journey BRI_BRO04_2020_01_28 with 31 stops
# Built journey BRI_BRO05_2020_01_28 with 31 stops
# Built journey BRI_BRO06_2020_01_28 with 31 stops
# Built journey BRI_BRO07_2020_01_28 with 31 stops
# Built journey BRI_BRO08_2020_01_28 with 31 stops
# Built journey BRI_BRO09_2020_01_28 with 31 stops
# Built journey BRI_BRO10_2020_01_28 with 31 stops
# Built journey BRI_BRO11_2020_01_28 with 31 stops
# Built journey BRI_BRO12_2020_01_28 with 31 stops
# Built journey BRI_BRO13_2020_01_28 with 31 stops
# Built journey BRI_BRO14_2020_01_28 with 31 stops
# Built journey BRI_BRO15_2020_01_28 with 31 stops
# Built journey BRI_BRO16_2020_01_28 with 31 stops
# Built journey BRI_BRO17_2020_01_28 with 31 stops
# Built journey BRI_BRO01_2020_01_29 with 31 stops
# Built journey BRI_BRO02_2020_01_29 with 31 stops
# Built journey BRI_BRO03_2020_01_29 with 31 stops
# Built journey BRI_BRO04_2020_01_29 with 31 stops
# Built journey BRI_BRO05_2020_01_29 with 31 stops
# Built journey BRI_BRO06_2020_01_29 with 31 stops
# Built journey BRI_BRO07_2020_01_29 with 31 stops
# Built journey BRI_BRO08_2020_01_29 with 31 stops
# Built journey BRI_BRO09_2020_01_29 with 31 stops
# Built journey BRI_BRO10_2020_01_29 with 31 stops
# Built journey BRI_BRO11_2020_01_29 with 31 stops
# Built journey BRI_BRO12_2020_01_29 with 31 stops
# Built journey BRI_BRO13_2020_01_29 with 31 stops
# Built journey BRI_BRO14_2020_01_29 with 31 stops
# Built journey BRI_BRO15_2020_01_29 with 31 stops
# Built journey BRI_BRO01_2020_01_30 with 31 stops
# Built journey BRI_BRO02_2020_01_30 with 31 stops
# Built journey BRI_BRO03_2020_01_30 with 31 stops
# Built journey BRI_BRO04_2020_01_30 with 31 stops
# Built journey BRI_BRO05_2020_01_30 with 31 stops
# Built journey BRI_BRO06_2020_01_30 with 31 stops
# Built journey BRI_BRO07_2020_01_30 with 31 stops
# Built journey BRI_BRO08_2020_01_30 with 31 stops
# Built journey BRI_BRO09_2020_01_30 with 31 stops
# Built journey BRI_BRO10_2020_01_30 with 31 stops
# Built journey BRI_BRO11_2020_01_30 with 31 stops
# Built journey BRI_BRO12_2020_01_30 with 31 stops
# Built journey BRI_BRO13_2020_01_30 with 31 stops
# Built journey BRI_BRO14_2020_01_30 with 31 stops
# Built journey BRI_BRO15_2020_01_30 with 31 stops
# Built journey BRI_BRO01_2020_01_31 with 31 stops
# Built journey BRI_BRO02_2020_01_31 with 31 stops
# Built journey BRI_BRO03_2020_01_31 with 31 stops
# Built journey BRI_BRO04_2020_01_31 with 31 stops
# Built journey BRI_BRO05_2020_01_31 with 31 stops
# Built journey BRI_BRO06_2020_01_31 with 31 stops
# Built journey BRI_BRO07_2020_01_31 with 31 stops
# Built journey BRI_BRO08_2020_01_31 with 31 stops
# Built journey BRI_BRO09_2020_01_31 with 31 stops
# Built journey BRI_BRO10_2020_01_31 with 31 stops
# Built journey BRI_BRO11_2020_01_31 with 31 stops
# Built journey BRI_BRO12_2020_01_31 with 31 stops
# Built journey BRI_BRO13_2020_01_31 with 31 stops
# Built journey BRI_BRO14_2020_01_31 with 31 stops
# Built journey BRI_BRO15_2020_01_31 with 31 stops
# Built journey BRI_BRO16_2020_01_31 with 31 stops
# Built journey BRI_BRO17_2020_01_31 with 31 stops
# Built journey BRI_BRO18_2020_01_31 with 31 stops
# Built journey BRI_BRO01_2020_02_01 with 31 stops
# Built journey BRI_BRO02_2020_02_01 with 31 stops
# Built journey BRI_BRO03_2020_02_01 with 31 stops
# Built journey BRI_BRO04_2020_02_01 with 31 stops
# Built journey BRI_BRO05_2020_02_01 with 31 stops
# Built journey BRI_BRO06_2020_02_01 with 31 stops
# Built journey BRI_BRO07_2020_02_01 with 31 stops
# Built journey BRI_BRO08_2020_02_01 with 31 stops
# Built journey BRI_BRO09_2020_02_01 with 31 stops
# Built journey BRI_BRO10_2020_02_01 with 31 stops
# Built journey BRI_BRO11_2020_02_01 with 31 stops
# Built journey BRI_BRO12_2020_02_01 with 31 stops
# Built journey BRI_BRO13_2020_02_01 with 31 stops
# Built journey BRI_BRO01_2020_02_02 with 31 stops
# Built journey BRI_BRO02_2020_02_02 with 31 stops
# Built journey BRI_BRO03_2020_02_02 with 31 stops
# Built journey BRI_BRO04_2020_02_02 with 31 stops
# Built journey BRI_BRO05_2020_02_02 with 31 stops
# Built journey BRI_BRO06_2020_02_02 with 31 stops
# Built journey BRI_BRO07_2020_02_02 with 31 stops
# Built journey BRI_BRO08_2020_02_02 with 31 stops
# Built journey BRI_BRO09_2020_02_02 with 31 stops
# Built journey BRI_BRO10_2020_02_02 with 31 stops
# Built journey BRI_BRO11_2020_02_02 with 31 stops
# Built journey BRI_BRO12_2020_02_02 with 31 stops
# Built journey BRI_BRO13_2020_02_02 with 31 stops
# Built journey BRI_BRO14_2020_02_02 with 31 stops
# Built journey BRI_BRO15_2020_02_02 with 31 stops
# Built journey BRI_BRO16_2020_02_02 with 31 stops
# Built journey BRI_BRO17_2020_02_02 with 31 stops
# Built journey BRI_BRO18_2020_02_02 with 31 stops
# Built journey BRI_BRO19_2020_02_02 with 31 stops
# Built journey BRI_BRO20_2020_02_02 with 31 stops
# Built journey BRI_BRO21_2020_02_02 with 31 stops
# Built journey BRI_BRO22_2020_02_02 with 31 stops
# Built journey BRI_BRO23_2020_02_02 with 31 stops
# Built journey BRI_BRO24_2020_02_02 with 31 stops
# Built journey BRI_BRO25_2020_02_02 with 31 stops
# Built journey BRI_BRO26_2020_02_02 with 31 stops
# Built journey BRI_BRO27_2020_02_02 with 31 stops
# Built journey BRI_BRO28_2020_02_02 with 31 stops
# Built journey BRI_BRO29_2020_02_02 with 31 stops
# Built journey BRI_BRO30_2020_02_02 with 31 stops
# Built journey BRI_BRO31_2020_02_02 with 31 stops
# Built journey BRI_BRO32_2020_02_02 with 31 stops
# Built journey BRI_BRO33_2020_02_02 with 31 stops
# Built journey BRI_BRO34_2020_02_02 with 31 stops
# Built journey BRI_BRO35_2020_02_02 with 31 stops
# Built journey BRI_BRO36_2020_02_02 with 31 stops
# Built journey BRI_BRO37_2020_02_02 with 31 stops
# Built journey BRI_BRO38_2020_02_02 with 31 stops
# Built journey BRI_BRO39_2020_02_02 with 31 stops
# Built journey BRI_BRO40_2020_02_02 with 31 stops
# Built journey BRI_BRO41_2020_02_02 with 31 stops
# Built journey BRI_BRO42_2020_02_02 with 31 stops
# Built journey BRI_BRO43_2020_02_02 with 31 stops
# Built journey BRI_BRO44_2020_02_02 with 31 stops
# Built journey BRI_BRO45_2020_02_02 with 31 stops
# Built journey BRI_BRO46_2020_02_02 with 31 stops
# Built journey BRI_BRO47_2020_02_02 with 31 stops
# Built journey BRI_BRO48_2020_02_02 with 31 stops
# Built journey BRI_BRO49_2020_02_02 with 31 stops
# Built journey BRI_BRO50_2020_02_02 with 31 stops
# Built journey BRI_BRO51_2020_02_02 with 31 stops
# Built journey BRI_BRO52_2020_02_02 with 31 stops
# Built journey BRI_BRO53_2020_02_02 with 31 stops
# Built journey BRI_BRO01_2020_02_03 with 31 stops
# Built journey BRI_BRO02_2020_02_03 with 31 stops
# Built journey BRI_BRO03_2020_02_03 with 31 stops
# Built journey BRI_BRO04_2020_02_03 with 31 stops
# Built journey BRI_BRO05_2020_02_03 with 31 stops
# Built journey BRI_BRO06_2020_02_03 with 31 stops
# Built journey BRI_BRO07_2020_02_03 with 31 stops
# Built journey BRI_BRO08_2020_02_03 with 31 stops
# Built journey BRI_BRO09_2020_02_03 with 31 stops
# Built journey BRI_BRO10_2020_02_03 with 31 stops
# Built journey BRI_BRO11_2020_02_03 with 31 stops
# Built journey BRI_BRO12_2020_02_03 with 31 stops
# Built journey BRI_BRO13_2020_02_03 with 31 stops
# Built journey BRI_BRO14_2020_02_03 with 31 stops
# Built journey BRI_BRO15_2020_02_03 with 31 stops
# Built journey BRI_BRO16_2020_02_03 with 31 stops
# Built journey BRI_BRO17_2020_02_03 with 31 stops
# Built journey BRI_BRO18_2020_02_03 with 31 stops
# Built journey BRI_BRO01_2020_02_04 with 31 stops
# Built journey BRI_BRO02_2020_02_04 with 31 stops
# Built journey BRI_BRO03_2020_02_04 with 31 stops
# Built journey BRI_BRO04_2020_02_04 with 31 stops
# Built journey BRI_BRO05_2020_02_04 with 31 stops
# Built journey BRI_BRO06_2020_02_04 with 31 stops
# Built journey BRI_BRO07_2020_02_04 with 31 stops
# Built journey BRI_BRO08_2020_02_04 with 31 stops
# Built journey BRI_BRO09_2020_02_04 with 31 stops
# Built journey BRI_BRO10_2020_02_04 with 31 stops
# Built journey BRI_BRO11_2020_02_04 with 31 stops
# Built journey BRI_BRO12_2020_02_04 with 31 stops
# Built journey BRI_BRO13_2020_02_04 with 31 stops
# Built journey BRI_BRO14_2020_02_04 with 31 stops
# Built journey BRI_BRO15_2020_02_04 with 31 stops
# Built journey BRI_BRO16_2020_02_04 with 31 stops
# Built journey BRI_BRO17_2020_02_04 with 31 stops
# Built journey BRI_BRO18_2020_02_04 with 31 stops
# Built journey BRI_BRO19_2020_02_04 with 31 stops
# Built journey BRI_BRO20_2020_02_04 with 31 stops
# Built journey BRI_BRO21_2020_02_04 with 31 stops
# Built journey BRI_BRO22_2020_02_04 with 31 stops
# Built journey BRI_BRO01_2020_02_05 with 31 stops
# Built journey BRI_BRO02_2020_02_05 with 31 stops
# Built journey BRI_BRO03_2020_02_05 with 31 stops
# Built journey BRI_BRO04_2020_02_05 with 31 stops
# Built journey BRI_BRO05_2020_02_05 with 31 stops
# Built journey BRI_BRO06_2020_02_05 with 31 stops

# %%
print_journey(full_journeys, "BRI_BRO01_2020_01_20", stop_templates)
# Out:
# 🚋 TramJourney BRI_BRO01_2020_01_20 (BRI → BRO)
#
# 📍 BRI
#   2020-01-20 05:12:02 | Due in: 17.0 min
#   2020-01-20 05:14:02 | Due in: 15.0 min
#   2020-01-20 05:16:05 | Due in: 13.0 min
#   2020-01-20 05:18:07 | Due in: 11.0 min
#   2020-01-20 05:20:02 | Due in: 9.0 min
#   2020-01-20 05:22:02 | Due in: 7.0 min
#   2020-01-20 05:24:05 | Due in: 5.0 min
#   2020-01-20 05:26:05 | Due in: 3.0 min
#   2020-01-20 05:28:05 | Due in: 1.0 min
#   2020-01-20 05:30:02 | Due in: 0.0 min
#
# 📍 CHE
#   2020-01-20 05:12:05 | Due in: 18.0 min
#   2020-01-20 05:14:04 | Due in: 16.0 min
#   2020-01-20 05:16:05 | Due in: 14.0 min
#   2020-01-20 05:18:07 | Due in: 12.0 min
#   2020-01-20 05:20:05 | Due in: 10.0 min
#   2020-01-20 05:22:04 | Due in: 8.0 min
#   2020-01-20 05:24:05 | Due in: 6.0 min
#   2020-01-20 05:26:05 | Due in: 4.0 min
#   2020-01-20 05:28:05 | Due in: 2.0 min
#   2020-01-20 05:30:05 | Due in: 0.0 min
#
# 📍 LAU
#   2020-01-20 05:14:04 | Due in: 18.0 min
#   2020-01-20 05:16:05 | Due in: 16.0 min
#   2020-01-20 05:18:07 | Due in: 14.0 min
#   2020-01-20 05:20:05 | Due in: 12.0 min
#   2020-01-20 05:22:04 | Due in: 10.0 min
#   2020-01-20 05:24:05 | Due in: 8.0 min
#   2020-01-20 05:26:05 | Due in: 6.0 min
#   2020-01-20 05:28:05 | Due in: 4.0 min
#   2020-01-20 05:30:05 | Due in: 2.0 min
#   2020-01-20 05:32:05 | Due in: 2.0 min
#   2020-01-20 05:34:05 | Due in: 0.0 min
#
# 📍 CCK
#   2020-01-20 05:18:07 | Due in: 17.0 min
#   2020-01-20 05:20:04 | Due in: 15.0 min
#   2020-01-20 05:22:04 | Due in: 13.0 min
#   2020-01-20 05:24:05 | Due in: 11.0 min
#   2020-01-20 05:26:05 | Due in: 9.0 min
#   2020-01-20 05:28:05 | Due in: 7.0 min
#   2020-01-20 05:30:05 | Due in: 5.0 min
#   2020-01-20 05:32:05 | Due in: 4.0 min
#   2020-01-20 05:34:05 | Due in: 1.0 min
#   2020-01-20 05:36:05 | Due in: 0.0 min
#
# 📍 BAW
#   2020-01-20 05:20:04 | Due in: 18.0 min
#   2020-01-20 05:22:04 | Due in: 16.0 min
#   2020-01-20 05:24:05 | Due in: 14.0 min
#   2020-01-20 05:26:05 | Due in: 12.0 min
#   2020-01-20 05:28:05 | Due in: 10.0 min
#   2020-01-20 05:30:05 | Due in: 8.0 min
#   2020-01-20 05:32:04 | Due in: 7.0 min
#   2020-01-20 05:34:05 | Due in: 4.0 min
#   2020-01-20 05:36:05 | Due in: 1.0 min
#   2020-01-20 05:38:05 | Due in: 0.0 min
#
# 📍 LEO
#   2020-01-20 05:22:04 | Due in: 18.0 min
#   2020-01-20 05:24:05 | Due in: 16.0 min
#   2020-01-20 05:26:05 | Due in: 14.0 min
#   2020-01-20 05:28:05 | Due in: 12.0 min
#   2020-01-20 05:30:04 | Due in: 10.0 min
#   2020-01-20 05:32:04 | Due in: 9.0 min
#   2020-01-20 05:34:04 | Due in: 6.0 min
#   2020-01-20 05:36:05 | Due in: 3.0 min
#   2020-01-20 05:38:05 | Due in: 1.0 min
#
# 📍 GAL
#   2020-01-20 05:24:05 | Due in: 17.0 min
#   2020-01-20 05:26:05 | Due in: 15.0 min
#   2020-01-20 05:28:05 | Due in: 13.0 min
#   2020-01-20 05:30:04 | Due in: 11.0 min
#   2020-01-20 05:32:04 | Due in: 11.0 min
#   2020-01-20 05:34:04 | Due in: 8.0 min
#   2020-01-20 05:36:05 | Due in: 5.0 min
#   2020-01-20 05:38:05 | Due in: 2.0 min
#   2020-01-20 05:40:05 | Due in: 0.0 min
#
# 📍 GLE
#   2020-01-20 05:26:05 | Due in: 17.0 min
#   2020-01-20 05:28:05 | Due in: 15.0 min
#   2020-01-20 05:30:04 | Due in: 13.0 min
#   2020-01-20 05:32:04 | Due in: 13.0 min
#   2020-01-20 05:34:04 | Due in: 10.0 min
#   2020-01-20 05:36:04 | Due in: 7.0 min
#   2020-01-20 05:38:05 | Due in: 4.0 min
#   2020-01-20 05:40:05 | Due in: 2.0 min
#   2020-01-20 05:42:05 | Due in: 0.0 min
#
# 📍 CPK
#   2020-01-20 05:26:04 | Due in: 18.0 min
#   2020-01-20 05:28:04 | Due in: 16.0 min
#   2020-01-20 05:30:02 | Due in: 14.0 min
#   2020-01-20 05:32:04 | Due in: 14.0 min
#   2020-01-20 05:34:04 | Due in: 11.0 min
#   2020-01-20 05:36:04 | Due in: 8.0 min
#   2020-01-20 05:38:05 | Due in: 6.0 min
#   2020-01-20 05:40:04 | Due in: 3.0 min
#   2020-01-20 05:42:05 | Due in: 1.0 min
#   2020-01-20 05:44:05 | Due in: 0.0 min
#
# 📍 SAN
#   2020-01-20 05:30:02 | Due in: 17.0 min
#   2020-01-20 05:32:04 | Due in: 16.0 min
#   2020-01-20 05:34:04 | Due in: 13.0 min
#   2020-01-20 05:36:04 | Due in: 11.0 min
#   2020-01-20 05:38:05 | Due in: 8.0 min
#   2020-01-20 05:40:05 | Due in: 6.0 min
#   2020-01-20 05:42:05 | Due in: 4.0 min
#   2020-01-20 05:44:05 | Due in: 1.0 min
#   2020-01-20 05:46:04 | Due in: 0.0 min
#   2020-01-20 05:48:05 | Due in: 0.0 min
#
# 📍 STI
#   2020-01-20 05:30:04 | Due in: 18.0 min
#   2020-01-20 05:32:04 | Due in: 18.0 min
#   2020-01-20 05:34:04 | Due in: 15.0 min
#   2020-01-20 05:36:04 | Due in: 12.0 min
#   2020-01-20 05:38:04 | Due in: 9.0 min
#   2020-01-20 05:40:04 | Due in: 7.0 min
#   2020-01-20 05:42:05 | Due in: 5.0 min
#   2020-01-20 05:44:04 | Due in: 3.0 min
#   2020-01-20 05:46:04 | Due in: 1.0 min
#   2020-01-20 05:48:04 | Due in: 0.0 min
#   2020-01-20 05:50:04 | Due in: 0.0 min
#
# 📍 KIL
#   2020-01-20 05:34:04 | Due in: 17.0 min
#   2020-01-20 05:36:04 | Due in: 14.0 min
#   2020-01-20 05:38:04 | Due in: 11.0 min
#   2020-01-20 05:40:05 | Due in: 9.0 min
#   2020-01-20 05:42:05 | Due in: 7.0 min
#   2020-01-20 05:44:05 | Due in: 5.0 min
#   2020-01-20 05:46:04 | Due in: 3.0 min
#   2020-01-20 05:48:04 | Due in: 2.0 min
#   2020-01-20 05:50:05 | Due in: 2.0 min
#   2020-01-20 05:52:05 | Due in: 2.0 min
#   2020-01-20 05:54:05 | Due in: 0.0 min
#
# 📍 BAL
#   2020-01-20 05:34:04 | Due in: 19.0 min
#   2020-01-20 05:36:04 | Due in: 16.0 min
#   2020-01-20 05:38:04 | Due in: 13.0 min
#   2020-01-20 05:40:05 | Due in: 11.0 min
#   2020-01-20 05:42:05 | Due in: 9.0 min
#   2020-01-20 05:44:05 | Due in: 7.0 min
#   2020-01-20 05:46:04 | Due in: 5.0 min
#   2020-01-20 05:48:04 | Due in: 4.0 min
#   2020-01-20 05:50:05 | Due in: 4.0 min
#   2020-01-20 05:52:05 | Due in: 3.0 min
#   2020-01-20 05:54:05 | Due in: 1.0 min
#   2020-01-20 05:56:05 | Due in: 0.0 min
#
# 📍 DUN
#   2020-01-20 05:36:04 | Due in: 18.0 min
#   2020-01-20 05:38:04 | Due in: 15.0 min
#   2020-01-20 05:40:04 | Due in: 13.0 min
#   2020-01-20 05:42:04 | Due in: 11.0 min
#   2020-01-20 05:44:05 | Due in: 8.0 min
#   2020-01-20 05:46:04 | Due in: 6.0 min
#   2020-01-20 05:48:04 | Due in: 6.0 min
#   2020-01-20 05:50:04 | Due in: 5.0 min
#   2020-01-20 05:52:05 | Due in: 5.0 min
#   2020-01-20 05:54:05 | Due in: 3.0 min
#   2020-01-20 05:56:05 | Due in: 0.0 min
#
# 📍 WIN
#   2020-01-20 05:38:04 | Due in: 17.0 min
#   2020-01-20 05:40:04 | Due in: 15.0 min
#   2020-01-20 05:42:04 | Due in: 13.0 min
#   2020-01-20 05:44:05 | Due in: 10.0 min
#   2020-01-20 05:46:04 | Due in: 8.0 min
#   2020-01-20 05:48:04 | Due in: 8.0 min
#   2020-01-20 05:50:04 | Due in: 7.0 min
#   2020-01-20 05:52:05 | Due in: 7.0 min
#   2020-01-20 05:54:05 | Due in: 5.0 min
#   2020-01-20 05:56:04 | Due in: 2.0 min
#   2020-01-20 05:58:05 | Due in: 0.0 min
#
# 📍 MIL
#   2020-01-20 05:38:04 | Due in: 19.0 min
#   2020-01-20 05:40:04 | Due in: 16.0 min
#   2020-01-20 05:42:04 | Due in: 14.0 min
#   2020-01-20 05:44:05 | Due in: 12.0 min
#   2020-01-20 05:46:04 | Due in: 10.0 min
#   2020-01-20 05:48:04 | Due in: 9.0 min
#   2020-01-20 05:50:04 | Due in: 9.0 min
#   2020-01-20 05:52:05 | Due in: 9.0 min
#   2020-01-20 05:54:05 | Due in: 7.0 min
#   2020-01-20 05:56:04 | Due in: 4.0 min
#   2020-01-20 05:58:05 | Due in: 2.0 min
#   2020-01-20 06:00:04 | Due in: 0.0 min
#
# 📍 COW
#   2020-01-20 05:40:04 | Due in: 18.0 min
#   2020-01-20 05:42:04 | Due in: 16.0 min
#   2020-01-20 05:44:05 | Due in: 14.0 min
#   2020-01-20 05:46:04 | Due in: 12.0 min
#   2020-01-20 05:48:04 | Due in: 11.0 min
#   2020-01-20 05:50:04 | Due in: 11.0 min
#   2020-01-20 05:52:05 | Due in: 10.0 min
#   2020-01-20 05:54:05 | Due in: 8.0 min
#   2020-01-20 05:56:04 | Due in: 6.0 min
#   2020-01-20 05:58:05 | Due in: 4.0 min
#   2020-01-20 06:00:04 | Due in: 1.0 min
#   2020-01-20 06:02:04 | Due in: 0.0 min
#
# 📍 BEE
#   2020-01-20 05:42:04 | Due in: 18.0 min
#   2020-01-20 05:44:05 | Due in: 15.0 min
#   2020-01-20 05:46:04 | Due in: 13.0 min
#   2020-01-20 05:48:04 | Due in: 13.0 min
#   2020-01-20 05:50:04 | Due in: 12.0 min
#   2020-01-20 05:52:04 | Due in: 12.0 min
#   2020-01-20 05:54:05 | Due in: 10.0 min
#   2020-01-20 05:56:04 | Due in: 7.0 min
#   2020-01-20 05:58:03 | Due in: 5.0 min
#   2020-01-20 06:00:04 | Due in: 3.0 min
#   2020-01-20 06:02:04 | Due in: 0.0 min
#
# 📍 RAN
#   2020-01-20 05:44:04 | Due in: 17.0 min
#   2020-01-20 05:46:04 | Due in: 15.0 min
#   2020-01-20 05:48:04 | Due in: 14.0 min
#   2020-01-20 05:50:04 | Due in: 14.0 min
#   2020-01-20 05:52:04 | Due in: 13.0 min
#   2020-01-20 05:54:05 | Due in: 11.0 min
#   2020-01-20 05:56:04 | Due in: 9.0 min
#   2020-01-20 05:58:05 | Due in: 7.0 min
#   2020-01-20 06:00:04 | Due in: 4.0 min
#   2020-01-20 06:02:04 | Due in: 2.0 min
#   2020-01-20 06:04:05 | Due in: 0.0 min
#
# 📍 CHA
#   2020-01-20 05:44:04 | Due in: 18.0 min
#   2020-01-20 05:46:04 | Due in: 16.0 min
#   2020-01-20 05:48:04 | Due in: 16.0 min
#   2020-01-20 05:50:04 | Due in: 15.0 min
#   2020-01-20 05:52:04 | Due in: 15.0 min
#   2020-01-20 05:54:05 | Due in: 13.0 min
#   2020-01-20 05:56:04 | Due in: 10.0 min
#   2020-01-20 05:58:04 | Due in: 8.0 min
#   2020-01-20 06:00:04 | Due in: 6.0 min
#   2020-01-20 06:02:04 | Due in: 3.0 min
#   2020-01-20 06:04:05 | Due in: 1.0 min
#   2020-01-20 06:06:04 | Due in: 0.0 min
#
# 📍 HAR
#   2020-01-20 05:46:04 | Due in: 18.0 min
#   2020-01-20 05:48:04 | Due in: 18.0 min
#   2020-01-20 05:50:02 | Due in: 17.0 min
#   2020-01-20 05:52:04 | Due in: 17.0 min
#   2020-01-20 05:54:04 | Due in: 15.0 min
#   2020-01-20 05:56:04 | Due in: 12.0 min
#   2020-01-20 05:58:04 | Due in: 10.0 min
#   2020-01-20 06:00:03 | Due in: 8.0 min
#   2020-01-20 06:02:04 | Due in: 5.0 min
#   2020-01-20 06:04:04 | Due in: 3.0 min
#   2020-01-20 06:06:04 | Due in: 1.0 min
#   2020-01-20 06:08:04 | Due in: 0.0 min
#
# 📍 STS
#   2020-01-20 05:54:05 | Due in: 18.0 min
#   2020-01-20 05:56:02 | Due in: 15.0 min
#   2020-01-20 05:58:04 | Due in: 13.0 min
#   2020-01-20 06:00:03 | Due in: 11.0 min
#   2020-01-20 06:02:04 | Due in: 8.0 min
#   2020-01-20 06:04:05 | Due in: 6.0 min
#   2020-01-20 06:06:04 | Due in: 4.0 min
#   2020-01-20 06:08:06 | Due in: 2.0 min
#   2020-01-20 06:10:05 | Due in: 0.0 min
#
# 📍 DAW
#   2020-01-20 05:56:04 | Due in: 18.0 min
#   2020-01-20 05:58:04 | Due in: 15.0 min
#   2020-01-20 06:00:03 | Due in: 13.0 min
#   2020-01-20 06:02:04 | Due in: 10.0 min
#   2020-01-20 06:04:04 | Due in: 8.0 min
#   2020-01-20 06:06:04 | Due in: 6.0 min
#   2020-01-20 06:08:06 | Due in: 4.0 min
#   2020-01-20 06:10:05 | Due in: 2.0 min
#   2020-01-20 06:12:04 | Due in: 0.0 min
#
# 📍 WES
#   2020-01-20 05:58:04 | Due in: 19.0 min
#   2020-01-20 06:00:03 | Due in: 16.0 min
#   2020-01-20 06:02:04 | Due in: 14.0 min
#   2020-01-20 06:04:04 | Due in: 11.0 min
#   2020-01-20 06:06:04 | Due in: 9.0 min
#   2020-01-20 06:08:06 | Due in: 7.0 min
#   2020-01-20 06:10:05 | Due in: 5.0 min
#   2020-01-20 06:12:04 | Due in: 3.0 min
#   2020-01-20 06:14:04 | Due in: 1.0 min
#
# 📍 OGP
#   2020-01-20 06:00:03 | Due in: 18.0 min
#   2020-01-20 06:02:04 | Due in: 16.0 min
#   2020-01-20 06:04:04 | Due in: 13.0 min
#   2020-01-20 06:06:04 | Due in: 11.0 min
#   2020-01-20 06:08:06 | Due in: 9.0 min
#   2020-01-20 06:10:04 | Due in: 7.0 min
#   2020-01-20 06:12:04 | Due in: 5.0 min
#   2020-01-20 06:14:04 | Due in: 3.0 min
#   2020-01-20 06:16:07 | Due in: 0.0 min
#
# 📍 OUP
#   2020-01-20 06:02:04 | Due in: 18.0 min
#   2020-01-20 06:04:04 | Due in: 16.0 min
#   2020-01-20 06:06:04 | Due in: 14.0 min
#   2020-01-20 06:08:06 | Due in: 12.0 min
#   2020-01-20 06:10:04 | Due in: 10.0 min
#   2020-01-20 06:12:04 | Due in: 8.0 min
#   2020-01-20 06:14:04 | Due in: 5.0 min
#   2020-01-20 06:16:07 | Due in: 3.0 min
#   2020-01-20 06:18:06 | Due in: 0.0 min
#
# 📍 DOM
#   2020-01-20 06:08:05 | Due in: 17.0 min
#   2020-01-20 06:10:04 | Due in: 15.0 min
#   2020-01-20 06:12:04 | Due in: 13.0 min
#   2020-01-20 06:14:03 | Due in: 11.0 min
#   2020-01-20 06:16:07 | Due in: 8.0 min
#   2020-01-20 06:18:06 | Due in: 6.0 min
#   2020-01-20 06:20:03 | Due in: 3.0 min
#
# 📍 BRD
#   2020-01-20 06:08:05 | Due in: 18.0 min
#   2020-01-20 06:10:04 | Due in: 16.0 min
#   2020-01-20 06:12:04 | Due in: 14.0 min
#   2020-01-20 06:14:03 | Due in: 11.0 min
#   2020-01-20 06:16:07 | Due in: 9.0 min
#   2020-01-20 06:18:06 | Due in: 6.0 min
#   2020-01-20 06:20:03 | Due in: 4.0 min
#   2020-01-20 06:22:03 | Due in: 0.0 min
#
# 📍 GRA
#   2020-01-20 06:08:05 | Due in: 19.0 min
#   2020-01-20 06:10:04 | Due in: 17.0 min
#   2020-01-20 06:12:04 | Due in: 15.0 min
#   2020-01-20 06:14:03 | Due in: 13.0 min
#   2020-01-20 06:16:06 | Due in: 10.0 min
#   2020-01-20 06:18:06 | Due in: 7.0 min
#   2020-01-20 06:20:03 | Due in: 5.0 min
#   2020-01-20 06:22:03 | Due in: 0.0 min
#   2020-01-20 06:24:04 | Due in: 0.0 min
#
# 📍 PHI
#   2020-01-20 06:10:04 | Due in: 18.0 min
#   2020-01-20 06:12:04 | Due in: 15.0 min
#   2020-01-20 06:14:03 | Due in: 13.0 min
#   2020-01-20 06:16:06 | Due in: 11.0 min
#   2020-01-20 06:18:06 | Due in: 8.0 min
#   2020-01-20 06:20:03 | Due in: 5.0 min
#   2020-01-20 06:22:02 | Due in: 1.0 min
#   2020-01-20 06:24:04 | Due in: 0.0 min
#
# 📍 CAB
#   2020-01-20 06:10:04 | Due in: 19.0 min
#   2020-01-20 06:12:04 | Due in: 17.0 min
#   2020-01-20 06:14:01 | Due in: 15.0 min
#   2020-01-20 06:16:06 | Due in: 12.0 min
#   2020-01-20 06:18:03 | Due in: 9.0 min
#   2020-01-20 06:20:03 | Due in: 7.0 min
#   2020-01-20 06:22:03 | Due in: 2.0 min
#   2020-01-20 06:24:04 | Due in: 1.0 min
#   2020-01-20 06:26:03 | Due in: 0.0 min

# %%
def journey_stats(df):
    """
    Print basic statistics for tram journeys
    """
    if not {'TramJourneyID', 'DateTime', 'Origin', 'Destination'}.issubset(df.columns):
        print("Required columns not found in the DataFrame.")
        return

    df = df.copy()
    df["DateTime"] = pd.to_datetime(df["DateTime"])

    # Compute journey durations
    journey_times = df.groupby("TramJourneyID")["DateTime"].agg(["min", "max"])
    journey_times["duration_min"] = (journey_times["max"] - journey_times["min"]).dt.total_seconds() / 60

    print("Journey Duration")
    print(journey_times["duration_min"].describe())
    print()

    # Number of unique stops per journey
    stops_per_journey = df.groupby("TramJourneyID")["Origin"].nunique()
    print("Stops per Journey")
    print(stops_per_journey.describe())
    print()

    # Most common Origin → Destination routes
    routes = df.groupby("TramJourneyID").agg({"Destination": "first"})
    route_counts = routes.groupby([ "Destination"]).size().sort_values(ascending=False)
    print("Destination Counts")
    print(route_counts.head(10))

# %%
stats = journey_stats(full_journeys)
stats
# Out:
# Journey Duration
# count    4954.000000
# mean       67.292871
# std         7.730042
# min        26.016667
# 25%        63.983333
# 50%        67.950000
# 75%        71.945833
# max       130.000000
# Name: duration_min, dtype: float64
#
# Stops per Journey
# count    4954.000000
# mean       23.419257
# std         3.478532
# min         7.000000
# 25%        22.000000
# 50%        22.000000
# 75%        25.000000
# max        31.000000
# Name: Origin, dtype: float64
#
# Destination Counts
# Destination
# TAL    823
# BRI    804
# PAR    701
# BRO    634
# SAN    634
# TPT    525
# SAG    506
# CON    297
# HEU     18
# RED     12
# dtype: int64

# %%
journey_lengths = df.groupby("TramJourneyID").size()
print(journey_lengths.describe())
print(journey_lengths.sample(5))
# Out:
# count    23850.000000
# mean       239.537442
# std         42.687743
# min         63.000000
# 25%        217.000000
# 50%        231.000000
# 75%        260.000000
# max        676.000000
# dtype: float64
# TramJourneyID
# TPT_TAL22_2020_02_22    219
# BRO_BRI04_2020_03_03    304
# BRO_BRI13_2020_02_11    306
# SAN_PAR06_2020_03_18    160
# SAN_BRO23_2020_02_29    216
# dtype: int64
